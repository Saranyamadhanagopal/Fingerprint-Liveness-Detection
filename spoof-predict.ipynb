# %%
#%run spoof-detect-resnet.py ## load resnet model functions
#%run spoof-detect-cnn.py ### to load cnn model functions
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Predicting on single image: <br/>
# Please input bestModel file, img for predicting on single image <br/>
# use keyword classify to predict <br/>

# %%
classify('weights.RMSprop.transfer1.preprocess.best.hdf5', '/home/iotadmin/database/Precision samples/Precision data/Live/1A-Copy1.bmp')
# Out:
# Probabilities: Live Spoof [[0.50621736 0.49378267]]

# %% [markdown]
#
# #### Predicting on Multiple image: <br/>
# Please input Path, bestModel file and batch_size<br/>
# use keyword predict

# %%
predict('/home/iotadmin/database/Precision samples/Precision data', 'weights.adam.Precision.preprocess.best.hdf5',8)
# Out:
# Loading Best Model
# Found 6 images belonging to 2 classes.
# Predicting Model
# Probabilities: Live Spoof [[6.3363189e-01 3.6636809e-01]
#  [1.8596126e-01 8.1403875e-01]
#  [6.3363189e-01 3.6636809e-01]
#  [9.9005640e-01 9.9436827e-03]
#  [8.8463463e-07 9.9999917e-01]
#  [4.0681615e-02 9.5931840e-01]]
# please check results_CNN.csv in the path
